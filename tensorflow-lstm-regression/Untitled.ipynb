# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,100,10000,dtype = np.float32)

sin = np.sin(x)

plt.plot(sin)

# %%
print('preparing data..')
time_step = 3

for i in range(len(sin) - 3):
    print(sin[i:i+time_step])
# Out:
# preparing data..
# [0.         0.01000083 0.02000067]
# [0.01000083 0.02000067 0.0299985 ]
# [0.02000067 0.0299985  0.03999333]
# [0.0299985  0.03999333 0.04998416]
# [0.03999333 0.04998416 0.05997   ]
# [0.04998416 0.05997    0.06994984]
# [0.05997    0.06994984 0.07992267]
# [0.06994984 0.07992267 0.08988751]
# [0.07992267 0.08988751 0.09984337]
# [0.08988751 0.09984337 0.10978924]
# [0.09984337 0.10978924 0.11972412]
# [0.10978924 0.11972412 0.12964703]
# [0.11972412 0.12964703 0.13955699]
# [0.12964703 0.13955699 0.14945295]
# [0.13955699 0.14945295 0.159334  ]
# [0.14945295 0.159334   0.16919911]
# [0.159334   0.16919911 0.17904729]
# [0.16919911 0.17904729 0.18887755]
# [0.17904729 0.18887755 0.19868894]
# [0.18887755 0.19868894 0.20848045]
# [0.19868894 0.20848045 0.2182511 ]
# [0.20848045 0.2182511  0.22799991]
# [0.2182511  0.22799991 0.23772594]
# [0.22799991 0.23772594 0.24742818]
# [0.23772594 0.24742818 0.25710568]
# [0.24742818 0.25710568 0.26675746]
# ...

# %%
import pandas as pd

data = pd.read_csv('./temp_data.csv')

# %%
data.iloc[-5:]
# Out:
#      YEAR    JAN    FEB    MAR    APR    MAY    JUN    JUL    AUG    SEP  \
# 112  2013  24.56  26.59  30.62  32.66  34.46  32.44  31.07  30.76  31.04
# 113  2014  23.83  25.97  28.95  32.74  33.77  34.15  31.85  31.32  30.68
# 114  2015  24.58  26.89  29.07  31.87  34.09  32.48  31.88  31.52  31.55
# 115  2016  26.94  29.72  32.62  35.38  35.72  34.03  31.64  31.79  31.66
# 116  2017  26.45  29.46  31.60  34.95  35.84  33.82  31.88  31.72  32.22
#
#        OCT    NOV    DEC  ANNUAL  JAN-FEB  MAR-MAY  JUN-SEP  OCT-DEC
# 112  30.27  27.83  25.37   29.81    25.58    32.58    31.33    27.83
# 113  30.29  28.05  25.08   29.72    24.90    31.82    32.00    27.81
# 114  31.04  28.10  25.67   29.90    25.74    31.68    31.87    28.27
# 115  31.98  30.11  28.01   31.63    28.33    34.57    32.28    30.03
# 116  32.29  29.60  27.18   31.42    27.95    34.13    32.41    29.69
